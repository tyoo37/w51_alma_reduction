# %%
from casatools import table
tb = table()
# Out:
# measures data is not available
# data_update: path must exist as a directory and it must be owned by the user, path = /home/t.yoo/.casa/data
#
# ...
#
# The expected casa data was not found at measurespath. CASA may still work if the data can be found in datapath.
# The expected measures data was not found at measurespath. CASA may still work if the data can be found in datapath.
# visit https://casadocs.readthedocs.io/en/stable/notebooks/external-data.html for more information
#
# 2026-06-26 00:49:12	SEVERE	::casa
# 2026-06-26 00:49:12	SEVERE	::casa	data_update: path must exist as a directory and it must be owned by the user, path = /home/t.yoo/.casa/data
# 2026-06-26 00:49:12	SEVERE	::casa
# 2026-06-26 00:49:12	SEVERE	::casa	Warning: measurespath must exist as a directory and it must be owned by the user.
# 2026-06-26 00:49:12	SEVERE	::casa	Warning: no auto update is possible on this measurespath by this user.
# 2026-06-26 00:49:12	SEVERE	::casa
# ...
